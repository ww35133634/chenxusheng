# %% [markdown]
# ### 导入需要使用的库

# %%
import pandas as pd
from pyecharts import GeoLines, Style

# %% [markdown]
# ### 1. geolines官方案例

# %%
from pyecharts import GeoLines, Style

style = Style(
    title_top="#fff",
    title_pos = "center",
    width=1200,
    height=600,
    background_color="#404a59"
)

data_guangzhou = [
    ["广州", "上海"],
    ["广州", "北京"],
    ["广州", "南京"],
    ["广州", "重庆"],
    ["广州", "兰州"],
    ["广州", "杭州"]
]

geolines = GeoLines("GeoLines 示例", **style.init_style)
geolines.add("从广州出发", data_guangzhou, is_legend_show=False)
geolines.render()
geolines
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="fc3520ff370b4b3882b41a6baa9245ca" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_fc3520ff370b4b3882b41a6baa9245ca = echarts.init(document.getElementById('fc3520ff370b4b3882b41a6baa9245ca'), null, {renderer: 'canvas'});
# var option_fc3520ff370b4b3882b41a6baa9245ca = {
#     "title": [
#         {
#             "text": "GeoLines \u793a\u4f8b",
#             "subtext": "",
#             "left": "center",
#             "top": "#fff",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2191953,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "lines",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "zlevel": 2,
#             "effect": {
#                 "show": true,
#                 "period": 6,
#                 "trailLength": 0,
#                 "color": "#fff",
#                 "symbol": "circle",
#                 "symbolSize": 5
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.48,
#                             31.22
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.46,
#                             39.92
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5357\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             118.78,
#                             32.04
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.54,
#                             29.59
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5170\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             103.73,
#                             36.03
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "zlevel": 2,
#             "coordinateSystem": "geo",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.48,
#                         31.22,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.46,
#                         39.92,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.54,
#                         29.59,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         0
#                     ]

# %% [markdown]
# ### 2. 修改官方案例
#
# 配色网站https://color.adobe.com/zh/explore/newest/

# %%
from pyecharts import GeoLines, Style

style = Style(
    title_color="#BF2441",     # 标题字体改为白色
    title_pos = "center",      # 标题居中 
    width=980,                 # 调整宽和高
    height=600,
    background_color="#011526" # 图像背景颜色
)

style_geo = style.add(
    maptype="china",
    is_label_show=True,
    line_curve=0.1,
    line_opacity=1,
    geo_effect_symbol="plane",
    geo_effect_color='#FF1D00',
    geo_effect_symbolsize=15,
    label_color=['red'],
    label_pos="right",
    label_formatter="{b}",
    label_text_color="#000",
    label_text_size=14,
    geo_normal_color="#fff",
    geo_emphasis_color="#7CE8D5"
)

data_guangzhou = [
    ["广州", "上海"],
    ["广州", "北京"],
    ["广州", "南京"],
    ["广州", "重庆"],
    ["广州", "兰州"],
    ["广州", "杭州"]
]

geolines = GeoLines("GeoLines官方示例修改", **style.init_style)
geolines.add("从广州出发", data_guangzhou, is_legend_show=False,**style_geo)
geolines.render()
geolines
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="91dbb785862f4d2c824b6e037217a705" style="width:980px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_91dbb785862f4d2c824b6e037217a705 = echarts.init(document.getElementById('91dbb785862f4d2c824b6e037217a705'), null, {renderer: 'canvas'});
# var option_91dbb785862f4d2c824b6e037217a705 = {
#     "title": [
#         {
#             "text": "GeoLines\u5b98\u65b9\u793a\u4f8b\u4fee\u6539",
#             "subtext": "",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#BF2441",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5856147,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "lines",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "zlevel": 2,
#             "effect": {
#                 "show": true,
#                 "period": 6,
#                 "trailLength": 0,
#                 "color": "#FF1D00",
#                 "symbol": "path://M1705.06,1318.313v-89.254l-319.9-221.799l0.073-208.063c0.521-84.662-26.629-121.796-63.961-121.491c-37.332-0.305-64.482,36.829-63.961,121.491l0.073,208.063l-319.9,221.799v89.254l330.343-157.288l12.238,241.308l-134.449,92.931l0.531,42.034l175.125-42.917l175.125,42.917l0.531-42.034l-134.449-92.931l12.238-241.308L1705.06,1318.313z",
#                 "symbolSize": 15
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.48,
#                             31.22
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.46,
#                             39.92
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5357\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             118.78,
#                             32.04
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.54,
#                             29.59
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5170\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             103.73,
#                             36.03
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0.1,
#                     "type": "solid",
#                     "color": null
#                 }
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "zlevel": 2,
#             "coordinateSystem": "geo",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.48,
#                         31.22,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.46,
#                         39.92,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.54,
#                         29.59,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",

# %% [markdown]
# ### 3.南宁与周边城市的公路联系的相关数据预处理

# %% [markdown]
# ####  汽车班次数据获取：
#
# - 部分城市的汽车班次数据可以从这个网站获取，网址为：https://www.changtu.com/chezhan/
# - 获取的数据保存到Excel中，然后倒入Python进行预处理

# %%
roads = pd.read_excel('./data/公路数据.xlsx')
roads.head()
# Out:
#         出发地  目的地
# 0  南宁市琅东汽车站  北海市
# 1  南宁市琅东汽车站  广州市
# 2  南宁市琅东汽车站  深圳市
# 3  南宁市琅东汽车站  柳州市
# 4  南宁市琅东汽车站  桂林市

# %%
roads['出发地'] = "南宁"

# %%
roads['目的地'] = roads['目的地'].apply(lambda s:s.strip("市"))
roads.head()
# Out:
#   出发地 目的地
# 0  南宁  北海
# 1  南宁  广州
# 2  南宁  深圳
# 3  南宁  柳州
# 4  南宁  桂林

# %%
roads = roads.drop_duplicates()

# %%
road_pairs = roads.values.tolist()

# %%
road_pairs
# Out:
# [['南宁', '北海'],
#  ['南宁', '广州'],
#  ['南宁', '深圳'],
#  ['南宁', '柳州'],
#  ['南宁', '桂林'],
#  ['南宁', '防城港'],
#  ['南宁', '玉林'],
#  ['南宁', '梧州'],
#  ['南宁', '钦州'],
#  ['南宁', '贵港'],
#  ['南宁', '东莞'],
#  ['南宁', '东兴'],
#  ['南宁', '来宾'],
#  ['南宁', '百色'],
#  ['南宁', '贺州']]

# %% [markdown]
# ### 4.南宁与其它城市的公路联系可视化展示

# %%
style = Style(
    title_color="#fff",
    title_pos = "center",
    width=980,
    height=600,
    background_color="#404a59"
)

style_geo = style.add(
    maptype="广西",
    is_label_show=True,
    line_curve=0.15,
    line_opacity=0.9,
    legend_pos="right",
    geo_effect_symbol="triangle",
    geo_effect_symbolsize=15,
    label_color=['#a6c84c'],
    label_pos="right",
    label_formatter="{b}",
    label_text_color="#eee",
)

geolines = GeoLines("南宁与其它城市的公路联系", **style.init_style)
geolines.add(name = "从南宁出发",data = road_pairs,is_legend_show=False,**style_geo)
geolines.render('./html/roads.html')
geolines
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'guangxi': '/nbextensions/echarts-china-provinces-js/guangxi'
#         }
#     });
# </script>
#     <div id="430ac209fea9428b9aa79c636b50bcac" style="width:980px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'guangxi'], function(echarts) {
#
# var myChart_430ac209fea9428b9aa79c636b50bcac = echarts.init(document.getElementById('430ac209fea9428b9aa79c636b50bcac'), null, {renderer: 'canvas'});
# var option_430ac209fea9428b9aa79c636b50bcac = {
#     "title": [
#         {
#             "text": "\u5357\u5b81\u4e0e\u5176\u5b83\u57ce\u5e02\u7684\u516c\u8def\u8054\u7cfb",
#             "subtext": "",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3559481,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "lines",
#             "name": "\u4ece\u5357\u5b81\u51fa\u53d1",
#             "zlevel": 2,
#             "effect": {
#                 "show": true,
#                 "period": 6,
#                 "trailLength": 0,
#                 "color": "#fff",
#                 "symbol": "triangle",
#                 "symbolSize": 15
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u5317\u6d77",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             109.12,
#                             21.49
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u5e7f\u5dde",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             113.23,
#                             23.16
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u6df1\u5733",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             114.07,
#                             22.62
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u67f3\u5dde",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             109.4,
#                             24.33
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u6842\u6797",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             110.28,
#                             25.29
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u9632\u57ce\u6e2f",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             108.2,
#                             21.37
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u7389\u6797",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             110.09,
#                             22.38
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u68a7\u5dde",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             111.2,
#                             23.29
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u94a6\u5dde",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             108.37,
#                             21.57
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u8d35\u6e2f",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             109.36,
#                             23.06
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u4e1c\u839e",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         [
#                             113.75,
#                             23.04
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u4e1c\u5174",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         []
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u6765\u5bbe",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
#                         []
#                     ]
#                 },
#                 {
#                     "fromName": "\u5357\u5b81",
#                     "toName": "\u767e\u8272",
#                     "coords": [
#                         [
#                             108.33,
#                             22.84
#                         ],
